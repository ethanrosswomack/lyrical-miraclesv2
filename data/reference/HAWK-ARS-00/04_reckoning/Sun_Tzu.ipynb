# %% [markdown]
# # 📖 The Book Of Sun Tzu
# Welcome to the master notebook — an organized compendium of **Hawk Eye The Rapper's** lyrical archive, commentary, and dissected meaning across every project.
#
# Use the links below to navigate into each project realm.

# %% [markdown]
# ## 📚 Table of Contents
# ### Albums
# - _(No notebooks found in `Dev/Book_of_Sun_Tzu/HawkEye_Lyric_Book_Full/*`)_
#
# ### Singles
# - _(No notebooks found in `Dev/Book_of_Sun_Tzu/HawkEye_Lyric_Book_Full/*`)_
#
# ### EverLight’s Rite
# - _(No notebooks found in `Dev/Book_of_Sun_Tzu/EverLights_Rite_Dissection`)_
#
# ### Dissection Archive
# - _(No notebooks found in `Dev/Book_of_Sun_Tzu/EverLights_Rite_Dissection`)_
#
# ### Catalog Commentary
# - _(No notebooks found in `Dev/Book_of_Sun_Tzu/EverLights_Rite_Dissection`)_
